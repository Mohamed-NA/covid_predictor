# %% [markdown]
# # **Data Splitting Notebook**
#
# This notebook handles:
#
#
#  1. Splitting the data to training and testing for the features and the target column
#  2. Handling the unbalanced number of samples for the target column
#  3. Scaling the features

# %% [markdown]
# # Load Data

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("../data/Reinfection Engineered Dataset.csv")
df.head(15)
# Out:
#     Age  Gender  Region  Preexisting_Condition  COVID_Strain  Symptoms  \
# 0    69       1       0                      4             2         0
# 1    38       1       3                      0             4         0
# 2    41       0       4                      3             1         0
# 3    81       0       0                      0             2         2
# 4    50       0       4                      1             2         0
# 5    66       1       3                      1             3         1
# 6    76       0       3                      4             3         1
# 7    77       0       3                      2             4         1
# 8    79       0       2                      3             4         0
# 9    72       0       3                      1             0         2
# 10   20       1       3                      3             1         2
# 11   56       1       3                      0             0         0
# 12   35       0       3                      0             1         2
# 13   70       1       0                      3             0         2
# 14   77       1       4                      4             3         0
#
#     Severity  Hospitalized  ICU_Admission  Ventilator_Support  ...  \
# 0          3             1              0                   0  ...
# 1          3             0              0                   0  ...
# 2          1             1              1                   1  ...
# 3          1             0              0                   0  ...
# 4          1             0              0                   0  ...
# 5          3             0              0                   0  ...
# 6          0             1              1                   0  ...
# 7          2             0              0                   0  ...
# 8          2             0              0                   0  ...
# 9          1             0              0                   0  ...
# 10         2             0              0                   0  ...
# 11         0             0              0                   0  ...
# 12         1             0              0                   0  ...
# 13         3             0              0                   0  ...
# 14         3             0              0                   0  ...
#
#     Vaccine_to_Infection_Days  Infected_soon_after_vaccine  \
# 0                         -93                            0
# 1                         165                            0
# 2                        -352                            0
# 3                        -445                            0
# 4                        -117                            0
# 5                        -977                            0
# 6                         200                            0
# 7                        -409                            0
# 8                          63                            0
# 9                        -588                            0
# 10                        170                            0
# 11                         91                            0
# 12                         33                            0
# 13                       -187                            0
# 14                        102                            0
#
#     Hospital_Stay_Duration  Age_Preexisting  Vaccine_Infection  \
# 0                       13              276                -93
# 1                        4                0                  0
# 2                       50              123               -352
# 3                        9                0               -445
# 4                        3               50               -117
# 5                        5               66               -977
# 6                      122              304                  0
# 7                        6              154               -409
# 8                        4              237                  0
# 9                        6               72               -588
# 10                       6               60                  0
# 11                       4                0                  0
# 12                       4                0                  0
# 13                       6              210               -187
# 14                       7              308                  0
#
#     Smoke_Preexist  Vaccine_to_Reinfection  Vaccinated_Before_Infection  \
# 0                8                     -32                            0
# 1                0                     -61                            1
# 2                6                     509                            0
# 3                0                     276                            0
# 4                2                     258                            0
# 5                2                     590                            0
# 6                4                    -147                            1
# 7                2                     331                            0
# 8                3                     114                            1
# 9                0                     122                            0
# 10               6                     593                            1
# 11               0                      72                            1
# 12               0                      59                            1
# 13               6                     648                            0
# 14               8                      -6                            1
#
#     Recovery_per_Stay  Time_to_Reinfection_per_Recovery
# 0           21.571429                         -0.412541
# 1            4.600000                          4.333333
# 2            0.941176                          3.204082
# 3           54.600000                         -0.308958
# 4           10.250000                          3.357143
# 5          103.333333                         -0.623188
# 6            0.349593                          1.204545
# 7           34.142857                         -0.325000
# 8            3.000000                         11.062500
# 9           88.428571                         -0.751613
# 10           1.571429                         63.583333
# 11          12.200000                          2.629032
# 12           6.200000                          2.875000
# 13          13.000000                          5.010870
# 14           2.000000                          5.647059
#
# [15 rows x 33 columns]

# %% [markdown]
# # Split Data

# %%
X = df.drop(columns=['Reinfection'])
y = df['Reinfection']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
smote = SMOTE(random_state=42, sampling_strategy=0.5)  # 1:2 ratio
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
print("After SMOTE:", y_train_resampled.value_counts())
# Out:
# After SMOTE: Reinfection
# 0    2052
# 1    1026
# Name: count, dtype: int64

# %% [markdown]
# # Save the splitted data

# %%
X_train_resampled.to_csv("../data/splitted_data/X_train.csv", index=False)
y_train_resampled.to_csv("../data/splitted_data/y_train.csv", index=False)
X_test.to_csv("../data/splitted_data/X_test.csv", index=False)
y_test.to_csv("../data/splitted_data/y_test.csv", index=False)
